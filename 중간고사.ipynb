# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

df = pd.read_csv('./linear_regression_data_1.csv')
df
# Out:
#           x0        x1        x2  ...        x6        x7          y
# 0   1.168952  1.111236 -0.022801  ... -1.347353  2.021008   9.001601
# 1   0.235192  0.320886  0.018131  ...  1.040955  1.064961  -2.495328
# 2   1.015289 -0.108769  0.519113  ... -0.496834 -0.872858 -11.404420
# 3   0.163967 -0.749437  0.558107  ... -1.675939 -0.007789   8.583963
# 4  -0.276140  0.465290 -0.307914  ...  0.195465 -0.256214  -0.224764
# ..       ...       ...       ...  ...       ...       ...        ...
# 95 -0.599813 -1.987342 -1.488436  ...  1.809733  1.006881  24.244442
# 96 -0.008446  0.142123  0.313104  ... -0.439036  0.981806  22.188806
# 97  1.171872 -0.265439  0.060112  ... -0.497511 -1.125775  13.228569
# 98  0.948269 -0.365714 -0.123297  ...  0.454310 -2.466429  28.139289
# 99  1.235505 -1.167125  1.064943  ... -1.235598  1.416964  20.723457
#
# [100 rows x 9 columns]

# %%
x = df[['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7']]
y = df['y']
lr = LinearRegression()
lr.fit(x, y)
print(lr.coef_, lr.intercept_)
# Out:
# [ 2.11457641 -6.9601774  -3.03779475  4.91944769  5.89500682 -9.00296199
#   0.92165776  4.03950177] 3.915178995206678

# %%
h = torch.tensor([[0.5, 0.1, 0.4],
        [0.6, 0.1, 0.3],
        [0.8, 0.1, 0.1],
        [0.4, 0.3, 0.3],
        [0.2, 0.5, 0.3]])

y = torch.tensor([0, 1, 2, 1, 1])
import torch
import torch.nn as nn

# 다중 클래스 예제 (CrossEntropyLoss)
# y_true = torch.tensor([2, 0])  # 실제 값 (원-핫 인코딩이 아님, 클래스 인덱스로 전달)
# y_pred = torch.tensor([[0.1, 0.3, 0.6], [0.7, 0.2, 0.1]])  # 예측 값 (로짓 값)

criterion = nn.CrossEntropyLoss()
loss = criterion(h, y)
print(f"Cross Entropy 손실: {loss.item()}")
# Out:
# Cross Entropy 손실: 1.152364730834961

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import numpy as np

df = pd.read_csv('./knn_data.csv')
classifier = KNeighborsClassifier(n_neighbors=100)
x = df[['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9']]
y = df['y']

#knn 예측하기 x가 x0부터 9까지 존재
classifier.fit(x, y)
q = [-6, 4, 2, 1, 23, -23, 10, -21, 6, 0]
print(classifier.predict([q]))
# Out:
# [3]
# /home/user/바탕화면/programming/myvenv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv('./knn_data.csv')
df
# Out:
#             x0         x1         x2  ...         x8         x9  y
# 0    11.694998  -9.393097 -15.400413  ...  12.552109   8.855928  7
# 1     2.171617   2.596127  -5.720803  ...  -2.972901  -0.582116  0
# 2    14.199551  -9.849464 -15.522312  ...  27.848140 -14.296780  5
# 3     1.462859  -2.951129 -20.371269  ...  -3.625941   8.002318  6
# 4   -32.637779   7.470194  -8.705971  ...  -8.187053  -1.259766  3
# ..         ...        ...        ...  ...        ...        ... ..
# 295   3.459160  -1.953656 -12.681136  ... -12.452322  23.522002  4
# 296  16.596055  14.948263  15.556750  ...   4.433977   5.017974  0
# 297   5.674584   7.662037  -7.931412  ... -20.223991 -15.681436  6
# 298 -19.133704  13.159849  13.383821  ...  18.870866  13.730973  1
# 299 -14.265858   1.474843 -18.432934  ...  -2.730354 -13.579786  3
#
# [300 rows x 11 columns]

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

data = pd.read_csv("./hospital_patient_records.csv")

X = data.drop(columns='치료여부')
y = data['치료여부']
weight_mean = data['체중'].mean()
X['체중'] = X['체중'].fillna(weight_mean)
X = pd.get_dummies(X)

model = RandomForestClassifier()
model.fit(X, y)
# Out:
# RandomForestClassifier()

# %%
data = pd.read_csv("./hospital_patient_records.csv")
data.isnull
# Out:
# <bound method DataFrame.isnull of     성별  나이    체중   병명         진단일  치료여부
# 0   남성  80  85.0  고혈압  2022-01-02     0
# 1   여성  69  72.3   폐렴  2022-01-09     1
# 2   남성  21  61.0   폐렴  2022-01-16     1
# 3   남성  40  57.3  당뇨병  2022-01-23     0
# 4   남성  32  82.2   폐렴  2022-01-30     1
# ..  ..  ..   ...  ...         ...   ...
# 95  여성  77  58.1   폐렴  2023-10-29     1
# 96  여성  19  64.5   폐렴  2023-11-05     0
# 97  여성  18  72.4  당뇨병  2023-11-12     1
# 98  여성  65  68.3   감기  2023-11-19     1
# 99  남성  29  82.5  고혈압  2023-11-26     0
#
# [100 rows x 6 columns]>

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np

# 데이터 포인트 정의
data = np.array([[1, 3], [2, 2], [2, 4], [3, 3], [5, 2], [6, 2], [7, 2]])

# WCSS 저장 리스트
wcss = []

# 다양한 K 값에 대해 K-Means 수행 (데이터 포인트 개수를 초과하지 않도록 설정)
for k in range(1, len(data) + 1):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)

# 엘보우 방법을 위한 그래프 그리기
plt.plot(range(1, len(data) + 1), wcss)
plt.title('elbow')
plt.xlabel('K')
plt.ylabel('WCSS (Within-Cluster Sum of Squares)')
plt.show()

# %%
for i in wcss:
    print(i)
# Out:
# 35.142857142857146
# 6.0
# 4.0
# 3.0
# 1.5
# 0.5
# 0.0
